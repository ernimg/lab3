# %% [markdown]
# # Ernest Mgłosiek 165 IC A2 Lab2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_csv = pd.read_csv("samochody1tys.csv")

# %% [markdown]
# Tworzenie Series

# %%
ser = pd.Series([1,3,5,np.nan,6,8])

# %%
ser
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# Data Frame

# %%
dates = pd.date_range('20130101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index= dates)
df
# Out:
#                    0         1         2         3
# 2013-01-01 -0.768400  0.292223  0.310209 -0.344240
# 2013-01-02  0.496744  0.244935  1.776893  0.488132
# 2013-01-03  0.611596  0.758901 -0.706732  0.499929
# 2013-01-04 -1.110901 -1.400336 -0.019127 -0.890916
# 2013-01-05  0.419010 -0.267657 -0.722444  1.677661
# 2013-01-06  1.469995  0.266935  1.542862  0.071051

# %% [markdown]
# Pint Data

# %%
file_csv.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
file_csv.tail(3)
# Out:
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# 999  999    Volvo  XC 60 I         2016.0         Diesel             1969.0
#
#      przebieg      cena  wojewodztwo
# 997  168111.0   10900.0      Łódzkie
# 998  226500.0    5400.0  Małopolskie
# 999   13617.0  136900.0  Małopolskie

# %% [markdown]
# INDEX

# %%
file_csv.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# COLUMNS

# %%
file_csv.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
file_csv.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
file_csv.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
file_csv.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
file_csv.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
file_csv.sort_values(by="wojewodztwo")
# Out:
#       id       marka                 model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan           X-Trail III         2014.0         Diesel
# 126  126  Land Rover  Range Rover Sport II         2017.0         Diesel
# 848  848  Volkswagen             Golf Plus         2005.0         Diesel
# 119  119       Škoda            Octavia II         2010.0         Diesel
# 852  852     Citroën    C4 Grand Picasso I         2008.0         Diesel
# ..   ...         ...                   ...            ...            ...
# 144  144        Audi                 Q5 8R         2015.0         Diesel
# 34    34     Citroën              Xsara II         2002.0        Benzyna
# 816  816      Jaguar                X-Type         2004.0         Diesel
# 708  708       Volvo                V70 II         2003.0        Benzyna
# 268  268         BMW                X3 E83         2009.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# ...

# %% [markdown]
# Sekcja

# %%
file_csv['cena']
# Out:
# 0       75900.0
# 1       70900.0
# 2        9800.0
# 3       11900.0
# 4       49900.0
#          ...
# 995     33900.0
# 996     25400.0
# 997     10900.0
# 998      5400.0
# 999    136900.0
# Name: cena, Length: 1000, dtype: float64

# %%
file_csv[0:3]
# Out:
#    id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
# 1   1     BMW       X1 E84         2012.0         Diesel             2000.0
# 2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 0  160000.0  75900.0    Dolnośląskie
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
file_csv.loc[:, ['model','rodzaj_silnika']]
# Out:
#            model rodzaj_silnika
# 0    X-Trail III         Diesel
# 1         X1 E84         Diesel
# 2       Zafira A    Benzyna+CNG
# 3          i10 I        Benzyna
# 4             CC         Diesel
# ..           ...            ...
# 995          159         Diesel
# 996     Fabia II        Benzyna
# 997        Modus        Benzyna
# 998        A3 8L        Benzyna
# 999      XC 60 I         Diesel
#
# [1000 rows x 2 columns]

# %%
file_csv.loc[50,['model','rodzaj_silnika']]
# Out:
# model             Scenic I
# rodzaj_silnika      Diesel
# Name: 50, dtype: object

# %% [markdown]
# Wybor przez pozycje

# %%
file_csv.iloc[562]
# Out:
# id                                  562
# marka                            Suzuki
# model                   Grand Vitara II
# rok_produkcji                      2006
# rodzaj_silnika                  Benzyna
# pojemnosc_silnika                  1995
# przebieg                         138000
# cena                              27900
# wojewodztwo          Zachodniopomorskie
# Name: 562, dtype: object

# %%
file_csv.iloc[3:10, 2:4]
# Out:
#        model  rok_produkcji
# 3      i10 I         2008.0
# 4         CC         2010.0
# 5        500         2014.0
# 6  X-Trail I         2004.0
# 7  Toledo II         2000.0
# 8         CC         2014.0
# 9       Juke         2016.0

# %%
file_csv.iloc[[1, 2, 4], [0, 2]]
# Out:
#    id     model
# 1   1    X1 E84
# 2   2  Zafira A
# 4   4        CC

# %%
file_csv.iloc[1:3, :]
# Out:
#    id marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1   BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2  Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
file_csv.iloc[: , 1:3]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %% [markdown]
# Boolean index

# %%
file_csv[file_csv.rok_produkcji > 2016]
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 17    17  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 18    18     Volkswagen     Tiguan II         2017.0         Diesel
# 20    20          Honda       CR-V IV         2017.0        Benzyna
# 21    21  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 32    32         Suzuki   SX4 S-Cross         2017.0        Benzyna
# ..   ...            ...           ...            ...            ...
# 967  967           Audi         A6 C7         2017.0         Diesel
# 985  985           Fiat           500         2017.0        Benzyna
# 988  988            BMW            M2         2017.0        Benzyna
# 992  992        Renault       Clio IV         2017.0        Benzyna
# 993  993           Fiat       Tipo II         2017.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena          wojewodztwo
# 17              1950.0       5.0  258709.0              Łódzkie
# ...

# %%
file_csv[file_csv['marka'].isin(['Nissan'])]
# Out:
#       id   marka        model  rok_produkcji rodzaj_silnika  \
# 0      0  Nissan  X-Trail III         2014.0         Diesel
# 6      6  Nissan    X-Trail I         2004.0         Diesel
# 9      9  Nissan         Juke         2016.0        Benzyna
# 42    42  Nissan   Qashqai II         2017.0        Benzyna
# 71    71  Nissan  X-Trail III         2017.0         Diesel
# 77    77  Nissan    Qashqai+2         2009.0        Benzyna
# 135  135  Nissan    Qashqai I         2013.0         Diesel
# 181  181  Nissan   Almera N16         2006.0        Benzyna
# 262  262  Nissan      Note II         2013.0        Benzyna
# 307  307  Nissan         Juke         2012.0        Benzyna
# 407  407  Nissan   Terrano II         2001.0         Diesel
# 448  448  Nissan         Juke         2010.0        Benzyna
# 472  472  Nissan   Qashqai II         2017.0         Diesel
# 576  576  Nissan  Primera P12         2003.0         Diesel
# 577  577  Nissan    X-Trail I         2003.0        Benzyna
# ...

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
df.at[dates[0], 'A'] = 0
df.iat[0, 1] = 0
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    0         1         2         3    A  D
# 2013-01-01 -0.768400  0.000000  0.310209 -0.344240  0.0  5
# 2013-01-02  0.496744  0.244935  1.776893  0.488132  NaN  5
# 2013-01-03  0.611596  0.758901 -0.706732  0.499929  NaN  5
# 2013-01-04 -1.110901 -1.400336 -0.019127 -0.890916  NaN  5
# 2013-01-05  0.419010 -0.267657 -0.722444  1.677661  NaN  5
# 2013-01-06  1.469995  0.266935  1.542862  0.071051  NaN  5

# %% [markdown]
# Miss Data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    0         1         2         3    A  D    E
# 2013-01-01 -0.768400  0.000000  0.310209 -0.344240  0.0  5  1.0
# 2013-01-02  0.496744  0.244935  1.776893  0.488132  NaN  5  1.0
# 2013-01-03  0.611596  0.758901 -0.706732  0.499929  NaN  5  NaN
# 2013-01-04 -1.110901 -1.400336 -0.019127 -0.890916  NaN  5  NaN

# %%
df1.dropna(how='any')
# Out:
#                  0    1         2        3    A  D    E
# 2013-01-01 -0.7684  0.0  0.310209 -0.34424  0.0  5  1.0

# %%
df1.fillna(value=5)
# Out:
#                    0         1         2         3    A  D    E
# 2013-01-01 -0.768400  0.000000  0.310209 -0.344240  0.0  5  1.0
# 2013-01-02  0.496744  0.244935  1.776893  0.488132  5.0  5  1.0
# 2013-01-03  0.611596  0.758901 -0.706732  0.499929  5.0  5  5.0
# 2013-01-04 -1.110901 -1.400336 -0.019127 -0.890916  5.0  5  5.0

# %%
pd.isna(df1)
# Out:
#                 0      1      2      3      A      D      E
# 2013-01-01  False  False  False  False  False  False  False
# 2013-01-02  False  False  False  False   True  False  False
# 2013-01-03  False  False  False  False   True  False   True
# 2013-01-04  False  False  False  False   True  False   True

# %% [markdown]
# OPERATION

# %%
file_csv.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
file_csv.apply(np.cumsum)
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# ..      ...                                                ...
# 995  495510  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 996  496506  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 997  497503  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 998  498501  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 999  499500  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
#
#                                                  model  rok_produkcji  \
# 0                                          X-Trail III         2014.0
# ...

# %% [markdown]
# JOIN

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %% [markdown]
# APPEND

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.067163  0.071121 -0.487815  0.324775
# 1 -0.434950 -0.247223  0.566520  1.350882
# 2  0.931516 -0.912486  0.423196 -0.555043
# 3 -0.670461 -1.362413  1.396347  0.483188
# 4  1.019310 -0.137583  1.037195  0.420828
# 5 -0.948305 -1.125267  0.615321  1.039294
# 6 -0.478291 -0.331223 -1.419129  1.456627
# 7  0.980188 -1.150197 -0.173307  0.380140
# 8 -0.670461 -1.362413  1.396347  0.483188

# %% [markdown]
# GROUPING

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                       'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                       'D': np.random.randn(8)})
print(df)
df.groupby('A').sum()
# Out:
#      A      B         C         D
# 0  foo    one  0.132834  0.139683
# 1  bar    one  0.143651 -0.625551
# 2  foo    two -0.840293  0.034358
# 3  bar  three  1.010710 -1.635123
# 4  foo    two -1.075496 -0.039179
# 5  bar    two -0.120537  1.393405
# 6  foo    one  0.680612  1.900015
# 7  foo  three -1.624576 -0.077586
#             C         D
# A
# bar  1.033824 -0.867269
# foo -2.726918  1.957292

# %% [markdown]
# RESHAPING

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                      'foo', 'foo', 'qux', 'qux'],
                     ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one    -0.868840 -0.742367
#       two     0.813068 -0.631259
# baz   one    -0.295536 -0.290774
#       two     1.117845 -0.241045

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -0.868840
#                B   -0.742367
#        two     A    0.813068
#                B   -0.631259
# baz    one     A   -0.295536
#                B   -0.290774
#        two     A    1.117845
#                B   -0.241045
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.868840 -0.742367
#       two     0.813068 -0.631259
# baz   one    -0.295536 -0.290774
#       two     1.117845 -0.241045

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.868840  0.813068
#       B -0.742367 -0.631259
# baz   A -0.295536  1.117845
#       B -0.290774 -0.241045

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.868840 -0.295536
#        B -0.742367 -0.290774
# two    A  0.813068  1.117845
#        B -0.631259 -0.241045

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                    'B': ['A', 'B', 'C'] * 4,
                 'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D': np.random.randn(12),
                    'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -1.021416 -0.715143
# 1     one  B  foo  0.205087  0.012125
# 2     two  C  foo  0.359026  0.066913
# 3   three  A  bar -0.833415 -0.931517
# 4     one  B  bar -0.368364 -0.498315
# 5     one  C  bar -0.434981  0.308167
# 6     two  A  foo -1.457233  0.479348
# 7   three  B  foo  0.421008 -0.254294
# 8     one  C  foo -2.291456 -0.352653
# 9     one  A  bar  0.316300  0.820885
# 10    two  B  bar  0.442585  0.055317
# 11  three  C  bar  0.591380  0.119533

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.316300 -1.021416
#       B -0.368364  0.205087
#       C -0.434981 -2.291456
# three A -0.833415       NaN
#       B       NaN  0.421008
#       C  0.591380       NaN
# two   A       NaN -1.457233
#       B  0.442585       NaN
#       C       NaN  0.359026

# %% [markdown]
# TIME SERIES

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample('5Min').sum()

ts
# Out:
# 2012-01-01 00:00:00    474
# 2012-01-01 00:00:01     29
# 2012-01-01 00:00:02    472
# 2012-01-01 00:00:03    206
# 2012-01-01 00:00:04    419
#                       ...
# 2012-01-01 00:01:35    373
# 2012-01-01 00:01:36    377
# 2012-01-01 00:01:37    488
# 2012-01-01 00:01:38    398
# 2012-01-01 00:01:39    286
# Freq: S, Length: 100, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06   -0.557118
# 2012-03-07    0.135650
# 2012-03-08   -0.045026
# 2012-03-09    0.567570
# 2012-03-10    0.224834
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.557118
# 2012-03-07 00:00:00+00:00    0.135650
# 2012-03-08 00:00:00+00:00   -0.045026
# 2012-03-09 00:00:00+00:00    0.567570
# 2012-03-10 00:00:00+00:00    0.224834
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.557118
# 2012-03-06 19:00:00-05:00    0.135650
# 2012-03-07 19:00:00-05:00   -0.045026
# 2012-03-08 19:00:00-05:00    0.567570
# 2012-03-09 19:00:00-05:00    0.224834
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

ts = pd.Series(np.random.randn(len(rng)), index=rng)

ts
# Out:
# 2012-01-31    0.956830
# 2012-02-29    1.051859
# 2012-03-31   -0.030053
# 2012-04-30    0.354865
# 2012-05-31    0.868798
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

ps
# Out:
# 2012-01    0.956830
# 2012-02    1.051859
# 2012-03   -0.030053
# 2012-04    0.354865
# 2012-05    0.868798
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.956830
# 2012-02-01    1.051859
# 2012-03-01   -0.030053
# 2012-04-01    0.354865
# 2012-05-01    0.868798
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

ts = pd.Series(np.random.randn(len(prng)), prng)
    
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

ts.head()
# Out:
# 1990-03-01 09:00   -1.176395
# 1990-06-01 09:00   -0.092567
# 1990-09-01 09:00    0.003888
# 1990-12-01 09:00    0.879680
# 1991-03-01 09:00    0.920607
# Freq: H, dtype: float64

# %% [markdown]
# Categorical

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                 "good", "very good"])
    

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %% [markdown]
# WYKRESY

# %%
ts = pd.Series(np.random.randn(1000),
                index=pd.date_range('1/1/2000', periods=1000))
 

ts = ts.cumsum()

ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                      columns=['A', 'B', 'C', 'D'])
   

df = df.cumsum()

plt.figure()
df.plot()
plt.legend(loc='best')
